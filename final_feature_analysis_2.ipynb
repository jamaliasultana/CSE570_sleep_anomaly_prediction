# %%
from google.colab import drive
drive.mount('/content/drive')
# !ls
# Out:
# Mounted at /content/drive
# drive  sample_data

# %%
# %cd '/content/drive/MyDrive/CSE 570 Wireless Project/final_dataset'
# Out:
# /content/drive/MyDrive/CSE 570 Wireless Project/final_dataset

# %% [markdown]
# # Plotting Bar Code

# %%
import matplotlib.pyplot as plt
import numpy as np

# Dummy data
methods = ['One-Class SVM', 'Isolation Forest', 'Deep Learning','Random Forest', 'Ensemble Classifier']
f1_scores = [0.43, 0.09, 0.19, 0.19, 0.27]
precision_scores = [0.31, 0.4, 0.12, 0.38, 0.19]
recall_scores = [0.67, 0.05, 0.16, 0.12, 0.43]

# Bar plot setup
x = np.arange(len(methods))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots(figsize=(8, 6))

# Plotting bars with aesthetic colors
rects1 = ax.bar(x - width, f1_scores, width, label='F1 Score', color='#F9C0AB')
rects2 = ax.bar(x, precision_scores, width, label='Precision', color='#F4E0AF')
rects3 = ax.bar(x + width, recall_scores, width, label='Recall', color='#A8CD89')

# Adding labels, title, and custom x-axis tick labels
ax.set_xlabel('Methods', fontsize=12)
ax.set_ylabel('Scores', fontsize=12)
ax.set_title('F1 Score, Precision, and Recall for Each Method', fontsize=14, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(methods, rotation=15, fontsize=10)
ax.legend(fontsize=10)

# Annotating bars with their heights
def annotate_bars(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.2f}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=9)

annotate_bars(rects1)
annotate_bars(rects2)
annotate_bars(rects3)

fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Dummy data
methods = ['2018', '2019', '2021','2022']
f1_scores = [0.43, 0.37, 0.32, 0.27]
precision_scores = [0.31, 0.28, 0.41, 0.17]
recall_scores = [0.67, 0.53, 0.27, 0.62]

# Bar plot setup
x = np.arange(len(methods))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots(figsize=(8, 6))

# Plotting bars with aesthetic colors
rects1 = ax.bar(x - width, f1_scores, width, label='F1 Score', color='#F9C0AB')
rects2 = ax.bar(x, precision_scores, width, label='Precision', color='#A5B68D')
rects3 = ax.bar(x + width, recall_scores, width, label='Recall', color='#355F2E')

# Adding labels, title, and custom x-axis tick labels
ax.set_xlabel('Years', fontsize=12)
ax.set_ylabel('Scores', fontsize=12)
ax.set_title('F1 Score, Precision, and Recall for Each Method', fontsize=14, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(methods, rotation=15, fontsize=10)
ax.legend(fontsize=10)

# Annotating bars with their heights
def annotate_bars(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.2f}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=9)

annotate_bars(rects1)
annotate_bars(rects2)
annotate_bars(rects3)

fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Dummy data
methods = ['2018', '2019', '2021','2022']
f1_scores = [0.81,0.72,0.67,0.77]
precision_scores = [0.31, 0.4, 0.12, 0.38, 0.19]
recall_scores = [0.67, 0.05, 0.16, 0.12, 0.43]

# Bar plot setup
x = np.arange(len(methods))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots(figsize=(6, 4))

# Plotting bars with aesthetic colors
rects1 = ax.bar(x - width, f1_scores, width, color='#A8CD89')
# rects2 = ax.bar(x, precision_scores, width, label='Precision', color='#F4E0AF')
# rects3 = ax.bar(x + width, recall_scores, width, label='Recall', color='#A8CD89')

# Adding labels, title, and custom x-axis tick labels
ax.set_xlabel('Methods', fontsize=12)
ax.set_ylabel('BAC', fontsize=12)
ax.set_title('Balanced Accuracy Score for Each Method', fontsize=14, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(methods, rotation=15, fontsize=10)
ax.legend(fontsize=10)

# Annotating bars with their heights
def annotate_bars(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.2f}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom', fontsize=9)

annotate_bars(rects1)


fig.tight_layout()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt

# Data for the features
features = [
    'Duration Asleep Main',
    'Duration In Bed Main'
]
t_statistics = [2.222112222841311, 2.1831803771209004]
p_values = [0.02650103940783382, 0.02925662481947149]

# Plot 1: T-Statistic
plt.figure(figsize=(8, 6))
plt.bar(features, t_statistics, color='#A5B68D', alpha=0.7,width=0.2)
plt.axhline(y=2, color='red', linestyle='--', label='Threshold (t-statistic = 2)')
plt.title('T-Statistics for Features')
plt.ylabel('T-Statistic')
plt.xlabel('Features')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# Plot 2: P-Value
plt.figure(figsize=(8, 6))
plt.bar(features, p_values, color='#A5B68D', alpha=0.7,width=0.2)
plt.axhline(y=0.05, color='red', linestyle='--', label='Significance Threshold (p = 0.05)')
plt.title('P-Values for Features')
plt.ylabel('P-Value')
plt.xlabel('Features')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the features
features = [
    'Duration Asleep',
    'Duration In Bed'
]
t_statistics = [2.222112222841311, 2.1831803771209004]
p_values = [0.02650103940783382, 0.02925662481947149]

# Create custom x positions for closer bars
x_positions = np.arange(len(features))

# Plot 1: T-Statistic with reduced distance between bars
plt.figure(figsize=(4, 3))
plt.bar(x_positions, t_statistics, color='#A5B68D', alpha=0.7, width=0.1)  # Custom bar positions
plt.axhline(y=2, color='red', linestyle='--', label='Threshold (t-statistic = 2)')
plt.title('T-Statistics for Features')
plt.ylabel('T-Statistic')
plt.xlabel('Features')
plt.xticks(x_positions, features, rotation=45)  # Adjust x-ticks
plt.legend()
plt.tight_layout()
plt.show()

# Plot 2: P-Value with reduced distance between bars
plt.figure(figsize=(4, 3))
plt.bar(x_positions, p_values, color='#A5B68D', alpha=0.7, width=0.1)  # Custom bar positions
plt.axhline(y=0.05, color='red', linestyle='--', label='Significance Threshold (p = 0.05)')
plt.title('P-Values for Features')
plt.ylabel('P-Value')
plt.xlabel('Features')
plt.xticks(x_positions, features, rotation=45)  # Adjust x-ticks
plt.legend()
plt.tight_layout()
plt.show()

# %%
# prompt: write a code to read this csv /content/drive/MyDrive/CSE 570 Wireless Project/final_dataset/sleep_step_screen_allday_15_participants.csv

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
import shap

df_INS_W1 = pd.read_csv('/content/drive/MyDrive/CSE 570 Wireless Project/final_dataset/INS-W_1_sleep_step_screen_allday_100_participants.csv')
df_INS_W2 = pd.read_csv('/content/drive/MyDrive/CSE 570 Wireless Project/final_dataset/INS-W_2_sleep_step_screen_allday_100_participants.csv')
df_INS_W3 = pd.read_csv('/content/drive/MyDrive/CSE 570 Wireless Project/final_dataset/INS-W_3_sleep_step_screen_allday_100_participants.csv')
df_INS_W4 = pd.read_csv('/content/drive/MyDrive/CSE 570 Wireless Project/final_dataset/INS-W_4_sleep_step_screen_allday_100_participants.csv')

# %%
print(df_INS_W1.shape)
print(df_INS_W2.shape)
print(df_INS_W3.shape)
print(df_INS_W4.shape)
# Out:
# (7313, 199)
# (7580, 199)
# (7894, 199)
# (8197, 199)

# %%
df_INS_W2.head()
# Out:
#                  pid        date  \
# 0  INS-W_303#INS-W_2  2019-03-21
# 1  INS-W_303#INS-W_2  2019-03-22
# 2  INS-W_303#INS-W_2  2019-03-23
# 3  INS-W_303#INS-W_2  2019-03-24
# 4  INS-W_303#INS-W_2  2019-03-25
#
#    f_screen:phone_screen_rapids_avgdurationunlock:allday  \
# 0                                          35.737283
# 1                                           2.902666
# 2                                           1.152253
# 3                                           7.404358
# 4                                           1.262568
#
#    f_screen:phone_screen_rapids_avgdurationunlock_locmap_exercise:allday  \
# 0                                           0.999983
# 1                                           0.999983
# 2                                           0.999983
# 3                                           0.999983
# 4                                           0.999983
#
#    f_screen:phone_screen_rapids_avgdurationunlock_locmap_exercise_norm:allday  \
# ...

# %%
# Filter the sleep_data dataframe to calculate the average efficiency per pid
sleep_data=df_INS_W1.copy()
low_efficiency_pids = (
    sleep_data.groupby('pid')['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday']
    .mean()
    .reset_index()
    .query("`f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday` < 85")
)

# Get the list of pids with average efficiency below 60
low_efficiency_pid_list = low_efficiency_pids['pid'].tolist()

print(f"PIDs with average efficiency under 60: {low_efficiency_pid_list}")
# Out:
# PIDs with average efficiency under 60: ['INS-W_123#INS-W_1']

# %%
import pandas as pd

# Load the dataset
file_path = '/content/drive/MyDrive/CSE 570 Wireless Project/final_dataset/anomaly_detect_for_INS-W_1.csv'
data = pd.read_csv(file_path)

# Count anomalies for each PID
anomaly_counts = data.groupby('pid')['anomaly'].sum()

# Filter PIDs with exactly 1 anomaly
pids_with_one_anomaly = anomaly_counts[anomaly_counts == 1].index.tolist()

print("PIDs with exactly one anomaly in the entire time series:")
print(pids_with_one_anomaly)
# Out:
# PIDs with exactly one anomaly in the entire time series:
# ['INS-W_005#INS-W_1', 'INS-W_026#INS-W_1', 'INS-W_061#INS-W_1', 'INS-W_073#INS-W_1', 'INS-W_074#INS-W_1', 'INS-W_082#INS-W_1', 'INS-W_122#INS-W_1', 'INS-W_150#INS-W_1', 'INS-W_160#INS-W_1', 'INS-W_169#INS-W_1', 'INS-W_171#INS-W_1', 'INS-W_180#INS-W_1', 'INS-W_195#INS-W_1', 'INS-W_202#INS-W_1']

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Copy the sleep data
sleep_data = df_INS_W1.copy()

# Filter data for the first 'pid'
pid_data = sleep_data[sleep_data['pid'] == 'INS-W_005#INS-W_1']

# Ensure the 'date' column is in datetime format
pid_data['date'] = pd.to_datetime(pid_data['date'])

# print(len(pid_data))

# Aggregate over the 'pid' by taking the mean of efficiency columns for each date
agg_pid_data = (
    pid_data.groupby('date')[['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday']]
    .mean()  # Aggregate by taking the mean
)

# Plot the temporal analysis of average efficiency for the first 'pid'
plt.figure(figsize=(10, 6))
plt.plot(
    agg_pid_data.index,
    agg_pid_data['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'],
    label='Avg Efficiency Main',
    # Optional: Add markers for better visualization
)

plt.title('Temporal Analysis of Average Efficiency for First PID')
plt.xlabel('Date')
plt.ylabel('Average Efficiency')
plt.legend()

# Limit the number of x-axis ticks for better readability
plt.xticks(
    agg_pid_data.index[::5],  # Use only every 5th date for ticks
    rotation=45,
    ha='right',  # Rotate and align labels for better readability
    fontsize=10
)

plt.tight_layout()
plt.grid()
plt.show()
# Out:
# <ipython-input-16-a42f028899b0>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pid_data['date'] = pd.to_datetime(pid_data['date'])

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Copy the sleep data
sleep_data = df_INS_W1.copy()

# Filter data for the first 'pid'
pid_data = sleep_data[sleep_data['pid'] == 'INS-W_123#INS-W_1']

# Ensure the 'date' column is in datetime format
pid_data['date'] = pd.to_datetime(pid_data['date'])

# Aggregate over the 'pid' by taking the mean of efficiency columns for each date
agg_pid_data = (
    pid_data.groupby('date')[['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday']]
    .mean()  # Aggregate by taking the mean
)

# Add a new column for bins based on sleep efficiency
bins = [0, 70, 84, 90, 100]  # Bins for sleep efficiency
labels = [0, 1, 2, 3]  # Bin labels for classification
agg_pid_data['Efficiency_Bin'] = pd.cut(
    agg_pid_data['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'],
    bins=bins,
    labels=labels,
    right=True,
    include_lowest=True
)

# Plot the temporal analysis of average efficiency and bins for the first 'pid'
plt.figure(figsize=(12, 7))

# Line plot for average efficiency
plt.plot(
    agg_pid_data.index,
    agg_pid_data['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'],
    label='Avg Efficiency Main',
    color='blue'
)

# # Line plot for bins
# plt.plot(
#     agg_pid_data.index,
#     agg_pid_data['Efficiency_Bin'].astype(int),  # Convert bin labels to int for plotting
#     label='Efficiency Bin',
#     color='red',
#     linestyle='--',
#     marker='x'
# )

# Add titles and labels
# plt.title('Temporal Analysis of Average Efficiency and Bins for First PID')
plt.xlabel('Date')
plt.ylabel('Sleep Efficieny Score')
plt.legend()

# Limit the number of x-axis ticks for better readability
plt.xticks(
    agg_pid_data.index[::5],  # Use only every 5th date for ticks
    rotation=45,
    ha='right',  # Rotate and align labels for better readability
    fontsize=10
)

plt.tight_layout()
plt.grid()
plt.show()
# Out:
# <ipython-input-81-cc980dbb367a>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pid_data['date'] = pd.to_datetime(pid_data['date'])

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Copy the sleep data
sleep_data = df_INS_W1.copy()

# Filter data for the first 'pid'
pid_data = sleep_data[sleep_data['pid'] == 'INS-W_005#INS-W_1']

# Ensure the 'date' column is in datetime format
pid_data['date'] = pd.to_datetime(pid_data['date'])

# Aggregate over the 'pid' by taking the mean of efficiency columns for each date
agg_pid_data = (
    pid_data.groupby('date')[['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday']]
    .mean()  # Aggregate by taking the mean
)

# Add a new column for bins based on sleep efficiency
bins = [0, 70, 84, 90, 100]  # Bins for sleep efficiency
labels = [0, 1, 2, 3]  # Bin labels for classification
agg_pid_data['Efficiency_Bin'] = pd.cut(
    agg_pid_data['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'],
    bins=bins,
    labels=labels,
    right=True,
    include_lowest=True
)

# Plot the temporal analysis of average efficiency and bins for the first 'pid'
plt.figure(figsize=(12, 7))

# Line plot for bins
plt.plot(
    agg_pid_data.index,
    agg_pid_data['Efficiency_Bin'].astype(int),  # Convert bin labels to int for plotting
    label='Efficiency Bin',
    color='red',
    linestyle='-'
)

# Add titles and labels
# plt.title('Temporal Analysis of Average Efficiency and Bins for First PID')
plt.xlabel('Date')
plt.ylabel('Efficiency Bin')
plt.legend()

# Limit the number of x-axis ticks for better readability
plt.xticks(
    agg_pid_data.index[::5],  # Use only every 5th date for ticks
    rotation=45,
    ha='right',  # Rotate and align labels for better readability
    fontsize=10
)

plt.tight_layout()
plt.grid()
plt.show()
# Out:
# <ipython-input-8-8a6adf7d9b7c>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pid_data['date'] = pd.to_datetime(pid_data['date'])

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = '/content/drive/MyDrive/CSE 570 Wireless Project/final_dataset/anomaly_detect_for_INS-W_1.csv'
data = pd.read_csv(file_path)

# Filter data for the specified 'pid'
filtered_data = data[data['pid'] == 'INS-W_005#INS-W_1']

# Ensure the 'date' column is in datetime format
filtered_data['date'] = pd.to_datetime(filtered_data['date'])

# Plot the line graph for 'date' and 'bin_change'
if 'bin_change' in filtered_data.columns:
    plt.figure(figsize=(12, 7))
    plt.plot(
        filtered_data['date'],
        filtered_data['anomaly'],
        label='Bin Change',
        color='red',
        linestyle='-'
    )

    # Add titles and labels
    # plt.title('Temporal Analysis of Bin Changes for PID INS-W_123#INS-W_1')
    plt.xlabel('Date')
    plt.ylabel('Anomaly (No/Yes)')
    plt.legend()

    # Adjust x-axis for better readability
    plt.xticks(
        filtered_data['date'][::5],  # Show every 5th date for better readability
        rotation=45,
        ha='right',
        fontsize=10
    )

    plt.tight_layout()
    plt.grid()
    plt.show()
else:
    print("The 'bin_change' column does not exist in the dataset.")
# Out:
# <ipython-input-7-c380d797217a>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['date'] = pd.to_datetime(filtered_data['date'])

# %%
sleep_data=df_INS_W4.copy()
# Filter data for the first 'pid'
pid_data = sleep_data[sleep_data['pid'] == sleep_data['pid'].iloc[150]]

# Aggregate over the 'pid' by taking mean of avgefficiency columns for each date
agg_pid_data = pid_data.groupby('date')[['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday',
                                         'f_slp:fitbit_sleep_summary_rapids_avgefficiencymain_norm:allday']].mean()

# Plot the temporal analysis of avgefficiency for the first 'pid'
plt.figure(figsize=(10,6))
plt.plot(agg_pid_data.index, agg_pid_data['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain_norm:allday'], label='Avg Efficiency Main')
#plt.plot(agg_pid_data.index, agg_pid_data['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain_norm:allday'], label='Avg Efficiency Main Norm')
plt.title('Temporal Analysis of Average Efficiency for First PID')
plt.xlabel('Date')
plt.ylabel('Average Efficiency')
plt.legend()

# Limit the number of x-axis ticks for better readability
plt.xticks(agg_pid_data.index[::5], rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-b2723f44a81c> in <cell line: 19>()
#      17
#      18 # Limit the number of x-axis ticks for better readability
# ---> 19 plt.xticks(agg_pid_data.index[::5], rotation=45)
#      20 plt.tight_layout()
#      21 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in xticks(ticks, labels, minor, **kwargs)
#    2047     labels_out: list[Text] = []
#    2048     if labels is None:
# -> 2049         labels_out = ax.get_xticklabels(minor=minor)
#    2050         for l in labels_out:
#    2051             l._internal_update(kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      71
#      72         def wrapper(self, *args, **kwargs):
# ---> 73             return get_method(self)(*args, **kwargs)
#      74
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Function to normalize data (min-max normalization)
def normalize(series):
    return (series - series.min()) / (series.max() - series.min())

# Assuming 'sleep_data' is your dataset, making a copy as per your request


# Filter data for the first 'pid'
pid_data = sleep_data[sleep_data['pid'] == sleep_data['pid'].iloc[400]]

# Define the top 6 features (provided)
top_6_features = [
    'f_steps:fitbit_steps_summary_rapids_avgsumsteps:allday',
    'f_screen:phone_screen_rapids_avgdurationunlock_locmap_greens:allday',
    'f_screen:phone_screen_rapids_avgdurationunlock_locmap_home:allday',
    'f_steps:fitbit_steps_intraday_rapids_avgdurationactivebout:allday',
    'f_screen:phone_screen_rapids_avgdurationunlock:allday',
    'f_screen:phone_screen_rapids_avgdurationunlock_locmap_home:allday'
]

# Set up the subplot (6 subplots, one for each feature)
fig, axs = plt.subplots(len(top_6_features), 1, figsize=(10, 18), sharex=True)

# Plot sleep efficiency along with each feature in the 6 subplots
for i, feature in enumerate(top_6_features):
    # Aggregate over the 'pid' by taking the mean of sleep efficiency and each feature for each date
    agg_pid_data = pid_data.groupby('date')[[feature, 'f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday']].mean()

    # Normalize both sleep efficiency and the feature
    agg_pid_data['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'] = normalize(agg_pid_data['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'])
    agg_pid_data[feature] = normalize(agg_pid_data[feature])

    # Plot sleep efficiency
    axs[i].plot(agg_pid_data.index, agg_pid_data['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'], label='Sleep Efficiency', color='blue')

    # Plot the corresponding feature
    axs[i].plot(agg_pid_data.index, agg_pid_data[feature], label=feature.replace(':', ' '), color='orange')

    # Set title and labels
    axs[i].set_title(f'Sleep Efficiency vs {feature.replace(":", " ")}')
    axs[i].set_ylabel('Normalized Values')
    axs[i].grid(True)
    axs[i].legend()

# Set common x-axis label
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()

# %%
import pandas as pd
from sklearn.feature_selection import mutual_info_regression

# Select a valid subset of non-sleep-related columns
subset_columns = [
    'f_steps:fitbit_steps_summary_rapids_avgsumsteps:allday',
    'f_screen:phone_screen_rapids_avgdurationunlock:allday',
    'f_steps:fitbit_steps_intraday_rapids_avgdurationactivebout:allday',
    'f_steps:fitbit_steps_summary_rapids_minsumsteps:allday'
]

# Impute missing values with the median for these columns
filtered_imputed_subset = sleep_data[subset_columns].fillna(sleep_data[subset_columns].median())

# Ensure the sleep efficiency column is correctly aligned and impute its missing values
sleep_efficiency = sleep_data['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'].fillna(sleep_data['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'].median())

# Concatenate the sleep efficiency and non-sleep-related columns
final_filtered_data = pd.concat([sleep_efficiency, filtered_imputed_subset], axis=1)

# Recalculate correlations and mutual information
spearman_corr = final_filtered_data.corr(method='spearman')['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'].dropna()
kendall_corr = final_filtered_data.corr(method='kendall')['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'].dropna()

# Calculate Mutual Information
mutual_info = mutual_info_regression(final_filtered_data[subset_columns], final_filtered_data['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'])
mutual_info_series = pd.Series(mutual_info, index=subset_columns).sort_values(ascending=False)

# Combine results
correlation_results = pd.DataFrame({
    'Spearman': spearman_corr,
    'Kendall': kendall_corr,
    'Mutual Information': mutual_info_series
}).sort_values(by='Mutual Information', ascending=False)

# Show the top 10 correlations
print(correlation_results.head(10))
# Out:
#                                                     Spearman   Kendall  \
# f_steps:fitbit_steps_summary_rapids_avgsumsteps...  0.000944  0.000537
# f_steps:fitbit_steps_summary_rapids_minsumsteps...  0.000944  0.000537
# f_steps:fitbit_steps_intraday_rapids_avgduratio... -0.015388 -0.012859
# f_screen:phone_screen_rapids_avgdurationunlock:... -0.124824 -0.090858
# f_slp:fitbit_sleep_summary_rapids_avgefficiency...  1.000000  1.000000
#
#                                                     Mutual Information
# f_steps:fitbit_steps_summary_rapids_avgsumsteps...            0.285190
# f_steps:fitbit_steps_summary_rapids_minsumsteps...            0.284079
# f_steps:fitbit_steps_intraday_rapids_avgduratio...            0.265334
# f_screen:phone_screen_rapids_avgdurationunlock:...            0.010565
# f_slp:fitbit_sleep_summary_rapids_avgefficiency...                 NaN

# %%
# Ensure the 'date' column is in datetime format
sleep_data['date'] = pd.to_datetime(sleep_data['date'])

# Extract day of the week (0 = Monday, ..., 6 = Sunday)
sleep_data['day_of_week'] = sleep_data['date'].dt.dayofweek

# Mark weekdays (0-4) and weekends (5-6)
sleep_data['is_weekend'] = np.where(sleep_data['day_of_week'] >= 5, 1, 0)

# Group by 'pid' and 'date' to handle multiple rows per participant per date
grouped_sleep_data = sleep_data.groupby(['pid', 'date']).mean().reset_index()

# Calculate mean sleep efficiency for weekdays and weekends
mean_weekday_sleep_efficiency = grouped_sleep_data[grouped_sleep_data['is_weekend'] == 0]['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'].mean()
mean_weekend_sleep_efficiency = grouped_sleep_data[grouped_sleep_data['is_weekend'] == 1]['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'].mean()

# Display the results
print(f"Mean Weekday Sleep Efficiency: {mean_weekday_sleep_efficiency}")
print(f"Mean Weekend Sleep Efficiency: {mean_weekend_sleep_efficiency}")
# Out:
# Mean Weekday Sleep Efficiency: 94.18630058901768
# Mean Weekend Sleep Efficiency: 94.23317073170732

# %% [markdown]
# # Lagged Correlation with steps

# %%
# Ensure the 'date' column is in datetime format
sleep_data['date'] = pd.to_datetime(sleep_data['date'])

# Sort data by 'pid' and 'date' to ensure proper time-series alignment
sleep_data = sleep_data.sort_values(by=['pid', 'date'])

# Create lagged versions of the step count feature
sleep_data['lagged_steps_1day'] = sleep_data.groupby('pid')['f_steps:fitbit_steps_summary_rapids_avgsumsteps:allday'].shift(1)
sleep_data['lagged_steps_2days'] = sleep_data.groupby('pid')['f_steps:fitbit_steps_summary_rapids_avgsumsteps:allday'].shift(2)
sleep_data['lagged_steps_3days'] = sleep_data.groupby('pid')['f_steps:fitbit_steps_summary_rapids_avgsumsteps:allday'].shift(3)

# Calculate the correlation between sleep efficiency and lagged steps
corr_1day = sleep_data['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'].corr(sleep_data['lagged_steps_1day'])
corr_2days = sleep_data['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'].corr(sleep_data['lagged_steps_2days'])
corr_3days = sleep_data['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'].corr(sleep_data['lagged_steps_3days'])

# Display the cross-correlations
print(f"Correlation between steps 1 day earlier and sleep efficiency: {corr_1day}")
print(f"Correlation between steps 2 days earlier and sleep efficiency: {corr_2days}")
print(f"Correlation between steps 3 days earlier and sleep efficiency: {corr_3days}")
# Out:
# Correlation between steps 1 day earlier and sleep efficiency: -0.004413755562161393
# Correlation between steps 2 days earlier and sleep efficiency: -0.007884028659638637
# Correlation between steps 3 days earlier and sleep efficiency: -0.0022481762239239403

# %%
from sklearn.feature_selection import mutual_info_regression

# Drop any rows with missing values for this analysis
sleep_data_nonnull = sleep_data[['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday', 'lagged_steps_1day', 'lagged_steps_2days', 'lagged_steps_3days']].dropna()

# Features (lagged steps)
X = sleep_data_nonnull[['lagged_steps_1day', 'lagged_steps_2days', 'lagged_steps_3days']]

# Target (sleep efficiency)
y = sleep_data_nonnull['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday']

# Calculate Mutual Information between lagged steps and sleep efficiency
mi = mutual_info_regression(X, y)

# Display Mutual Information for each lag
for i, lag in enumerate(['1 day earlier', '2 days earlier', '3 days earlier']):
    print(f"Mutual Information between steps {lag} and sleep efficiency: {mi[i]}")
# Out:
# Mutual Information between steps 1 day earlier and sleep efficiency: 0.2255191086906052
# Mutual Information between steps 2 days earlier and sleep efficiency: 0.20108160606553405
# Mutual Information between steps 3 days earlier and sleep efficiency: 0.16488950692685833

# %%
# List all available columns in the dataset
available_columns = sleep_data.columns
print(available_columns)
# Out:
# Index(['pid', 'date', 'f_screen:phone_screen_rapids_avgdurationunlock:allday',
#        'f_screen:phone_screen_rapids_avgdurationunlock_locmap_exercise:allday',
#        'f_screen:phone_screen_rapids_avgdurationunlock_locmap_exercise_norm:allday',
#        'f_screen:phone_screen_rapids_avgdurationunlock_locmap_greens:allday',
#        'f_screen:phone_screen_rapids_avgdurationunlock_locmap_greens_norm:allday',
#        'f_screen:phone_screen_rapids_avgdurationunlock_locmap_home:allday',
#        'f_screen:phone_screen_rapids_avgdurationunlock_locmap_home_norm:allday',
#        'f_screen:phone_screen_rapids_avgdurationunlock_locmap_living:allday',
#        ...
#        'f_steps:fitbit_steps_summary_rapids_minsumsteps:allday',
#        'f_steps:fitbit_steps_summary_rapids_minsumsteps_norm:allday',
#        'f_steps:fitbit_steps_summary_rapids_stdsumsteps:allday',
#        'f_steps:fitbit_steps_summary_rapids_stdsumsteps_dis:allday',
# ...

# %%
# List of additional columns to explore
additional_columns = [
    'f_steps:fitbit_steps_intraday_rapids_avgdurationactivebout:allday',  # Average duration of active bouts
     # Total duration of active bouts
    'f_screen:phone_screen_rapids_avgdurationunlock:allday',  # Average screen unlock duration
    'f_screen:phone_screen_rapids_avgdurationunlock_locmap_home:allday',  # Screen unlock duration at home
     # Average sedentary bouts
]

# Impute missing values with the median for these columns
filtered_imputed_additional = sleep_data[additional_columns].fillna(sleep_data[additional_columns].median())

# Concatenate the sleep efficiency and the additional columns
final_data_additional = pd.concat([sleep_efficiency, filtered_imputed_additional], axis=1)

# Calculate the Spearman and Kendall correlations
spearman_corr_additional = final_data_additional.corr(method='spearman')['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'].dropna()
kendall_corr_additional = final_data_additional.corr(method='kendall')['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'].dropna()

# Display the results
print("Spearman Correlation:")
print(spearman_corr_additional)

print("\nKendall Correlation:")
print(kendall_corr_additional)
# Out:
# Spearman Correlation:
# f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday           1.000000
# f_steps:fitbit_steps_intraday_rapids_avgdurationactivebout:allday   -0.015388
# f_screen:phone_screen_rapids_avgdurationunlock:allday               -0.124824
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_home:allday   -0.114001
# Name: f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday, dtype: float64
#
# Kendall Correlation:
# f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday           1.000000
# f_steps:fitbit_steps_intraday_rapids_avgdurationactivebout:allday   -0.012859
# f_screen:phone_screen_rapids_avgdurationunlock:allday               -0.090858
# f_screen:phone_screen_rapids_avgdurationunlock_locmap_home:allday   -0.083853
# Name: f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday, dtype: float64

# %%
pip install shap

# %%
# Define the 20 selected features
selected_features = [
    'f_steps:fitbit_steps_summary_rapids_avgsumsteps:allday',
    'f_steps:fitbit_steps_summary_rapids_maxsumsteps:allday',
    'f_steps:fitbit_steps_summary_rapids_minsumsteps:allday',
    'f_steps:fitbit_steps_intraday_rapids_avgdurationactivebout:allday',
    'f_steps:fitbit_steps_intraday_rapids_maxdurationactivebout:allday',
    'f_screen:phone_screen_rapids_avgdurationunlock:allday',
    'f_screen:phone_screen_rapids_countepisodeunlock:allday',
    'f_screen:phone_screen_rapids_avgdurationunlock_locmap_home:allday',
    'f_screen:phone_screen_rapids_avgdurationunlock_locmap_living:allday',
    'f_screen:phone_screen_rapids_avgdurationunlock_locmap_exercise:allday',
    'f_screen:phone_screen_rapids_avgdurationunlock_locmap_greens:allday',
    'f_screen:phone_screen_rapids_avgdurationunlock_locmap_study:allday',
    'f_steps:fitbit_steps_intraday_rapids_stddurationactivebout:allday',
    'f_steps:fitbit_steps_summary_rapids_avgsumsteps_norm:allday',
    'f_steps:fitbit_steps_intraday_rapids_mindurationactivebout:allday'
]

# Prepare the data
X = sleep_data[selected_features].fillna(sleep_data[selected_features].median())  # Feature matrix
y = sleep_data['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'].fillna(sleep_data['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'].median())

# Train the Decision Tree model
model = DecisionTreeRegressor()
model.fit(X, y)

# Create a SHAP explainer
explainer = shap.Explainer(model, X)
shap_values = explainer(X)

# Plot the SHAP summary to see feature importance
shap.summary_plot(shap_values, X)
# Out:
#  97%|=================== | 7124/7313 [00:25<00:00]

# %%
import shap
import matplotlib.pyplot as plt

# Prepare the data
X = sleep_data[selected_features].fillna(sleep_data[selected_features].median())  # Feature matrix
y = sleep_data['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'].fillna(sleep_data['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'].median())

# Train the Decision Tree model
model = DecisionTreeRegressor()
model.fit(X, y)

# Create a SHAP explainer
explainer = shap.Explainer(model, X)
shap_values = explainer(X)

# Increase the figure size and decrease font size
plt.figure(figsize=(15, 20))  # Increase the width and height of the figure
shap.summary_plot(shap_values, X, show=False)

# Reduce font size of feature names and labels
plt.gca().tick_params(labelsize=5)  # Decrease label font size to 10

# Save or show the plot
plt.tight_layout()
plt.show()

## f_steps:fitbit_steps_summary_rapids_avgsumsteps:allday
# Out:
# 100%|===================| 7303/7313 [00:18<00:00]

# %%
sleep_data['date'] = pd.to_datetime(sleep_data['date'])

sleep_data['week'] = sleep_data['date'].dt.isocalendar().week

# Group by 'week' and calculate the mean sleep across all subjects
weekly_mean_sleep_efficiency = sleep_data.groupby('week')['f_slp:fitbit_sleep_summary_rapids_avgdurationinbedmain:allday'].mean()

# Plot the weekly mean of sleep
plt.figure(figsize=(10, 6))
plt.plot(weekly_mean_sleep_efficiency, marker='o', linestyle='-')
plt.title('Weekly Mean Sleep Across All Subjects')
plt.xlabel('Week')
plt.ylabel('Mean Sleep Efficiency')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your datasets
df_INS_W1 = pd.read_csv('/content/drive/MyDrive/CSE 570 Wireless Project/final_dataset/INS-W_1_sleep_step_screen_allday_100_participants.csv')
df_INS_W2 = pd.read_csv('/content/drive/MyDrive/CSE 570 Wireless Project/final_dataset/INS-W_2_sleep_step_screen_allday_100_participants.csv')
df_INS_W3 = pd.read_csv('/content/drive/MyDrive/CSE 570 Wireless Project/final_dataset/INS-W_3_sleep_step_screen_allday_100_participants.csv')
df_INS_W4 = pd.read_csv('/content/drive/MyDrive/CSE 570 Wireless Project/final_dataset/INS-W_4_sleep_step_screen_allday_100_participants.csv')

# Combine all datasets into dictionaries based on Pre-COVID and Post-COVID
datasets_pre_covid = {
    "2018": df_INS_W1,
    "2019": df_INS_W2
}

datasets_post_covid = {
    "2021": df_INS_W3,
    "2022": df_INS_W4
}

# Define the sleep column and ensure the sleep is in hours
sleep_column = "f_slp:fitbit_sleep_summary_rapids_avgdurationinbedmain:allday"
scale_factor = 60  # Assuming the sleep data is in minutes and needs to be converted to hours

def calculate_per_person_per_week_mean(datasets, scale_factor):
    weekly_data = {}
    for year, data in datasets.items():
        # Convert the 'date' column to datetime
        data['date'] = pd.to_datetime(data['date'])

        # Extract the week from the date
        data['week'] = data['date'].dt.isocalendar().week

        # Convert sleep duration to hours if necessary
        data[sleep_column] = data[sleep_column] / scale_factor

        # Group by 'pid' and 'week' to calculate the mean sleep per person per week
        per_person_per_week_mean = data.groupby(['pid', 'week'])[sleep_column].mean().reset_index()

        # Group by 'week' and calculate the overall mean per week (aggregating across participants)
        weekly_mean_per_person = per_person_per_week_mean.groupby('week')[sleep_column].mean()

        # Store the result for plotting
        weekly_data[year] = weekly_mean_per_person
    return weekly_data

# Calculate weekly mean sleep for Pre-COVID and Post-COVID
pre_covid_data = calculate_per_person_per_week_mean(datasets_pre_covid, scale_factor)
post_covid_data = calculate_per_person_per_week_mean(datasets_post_covid, scale_factor)

# Create subplots for Pre-COVID and Post-COVID
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plot Pre-COVID data (2018, 2019)
for year, weekly_mean in pre_covid_data.items():
    axes[0].plot(weekly_mean, marker='o', linestyle='-', label=year)

axes[0].set_title('Pre-COVID (2018, 2019)')
axes[0].set_xlabel('Week')
axes[0].set_ylabel('Mean Sleep Duration (hours)')
# axes[0].set_ylim(6, 9)  # Setting the y-axis range between 6 to 9 hours
axes[0].grid(True)
axes[0].legend()

# Plot Post-COVID data (2021, 2022)
for year, weekly_mean in post_covid_data.items():
    axes[1].plot(weekly_mean, marker='o', linestyle='-', label=year)

axes[1].set_title('Post-COVID (2021, 2022)')
axes[1].set_xlabel('Week')
axes[1].set_ylabel('Mean Sleep Duration (hours)')
# axes[1].set_ylim(6, 9)  # Setting the y-axis range between 6 to 9 hours
axes[1].grid(True)
axes[1].legend()

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# %%
# List all the columns in df_INS_W1 to find the correct sleep efficiency column
print(df_INS_W1.columns)
# Out:
# Index(['pid', 'date', 'f_screen:phone_screen_rapids_avgdurationunlock:allday',
#        'f_screen:phone_screen_rapids_avgdurationunlock_locmap_exercise:allday',
#        'f_screen:phone_screen_rapids_avgdurationunlock_locmap_exercise_norm:allday',
#        'f_screen:phone_screen_rapids_avgdurationunlock_locmap_greens:allday',
#        'f_screen:phone_screen_rapids_avgdurationunlock_locmap_greens_norm:allday',
#        'f_screen:phone_screen_rapids_avgdurationunlock_locmap_home:allday',
#        'f_screen:phone_screen_rapids_avgdurationunlock_locmap_home_norm:allday',
#        'f_screen:phone_screen_rapids_avgdurationunlock_locmap_living:allday',
#        ...
#        'f_steps:fitbit_steps_summary_rapids_maxsumsteps:allday',
#        'f_steps:fitbit_steps_summary_rapids_maxsumsteps_norm:allday',
#        'f_steps:fitbit_steps_summary_rapids_mediansumsteps:allday',
#        'f_steps:fitbit_steps_summary_rapids_mediansumsteps_norm:allday',
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset df_INS_W1
df_INS_W1 = pd.read_csv('/content/drive/MyDrive/CSE 570 Wireless Project/final_dataset/INS-W_1_sleep_step_screen_allday_100_participants.csv')

# After verifying, assign the correct column names
sleep_duration_column = "f_slp:fitbit_sleep_summary_rapids_avgdurationinbedmain:allday"

# Replace with the correct column name for sleep efficiency
sleep_efficiency_column = "f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday"  # <-- Update this with the correct name

# Ensure the date column is in datetime format
df_INS_W1['date'] = pd.to_datetime(df_INS_W1['date'])

# Sort by date to ensure proper order
df_INS_W1 = df_INS_W1.sort_values('date')

# Shift the sleep efficiency by 1 day to compare with the previous day's sleep duration
df_INS_W1['sleep_efficiency_shifted'] = df_INS_W1[sleep_efficiency_column].shift(-1)

# Drop any rows where either sleep duration or shifted sleep efficiency is NaN
df_clean = df_INS_W1[[sleep_duration_column, 'sleep_efficiency_shifted']].dropna()

# Calculate the auto-correlation between sleep duration and the shifted sleep efficiency
correlation = df_clean[sleep_duration_column].corr(df_clean['sleep_efficiency_shifted'])

# Plot the Sleep Duration vs. Next Day's Sleep Efficiency
plt.figure(figsize=(8, 6))
plt.scatter(df_clean[sleep_duration_column], df_clean['sleep_efficiency_shifted'], alpha=0.6)
plt.title(f'Sleep Duration vs Next Day Sleep Efficiency\nAuto-correlation: {correlation:.2f}')
plt.xlabel('Sleep Duration (n-th day) [minutes]')
plt.ylabel('Sleep Efficiency (n+1-th day) [%]')
plt.grid(True)
plt.tight_layout()
plt.show()

# Print the calculated correlation
print(f"Auto-correlation between Sleep Duration (n-th day) and Sleep Efficiency (n+1-th day): {correlation:.2f}")
# Out:
# Auto-correlation between Sleep Duration (n-th day) and Sleep Efficiency (n+1-th day): 0.01

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset df_INS_W1
df_INS_W1 = pd.read_csv('/content/drive/MyDrive/CSE 570 Wireless Project/final_dataset/INS-W_1_sleep_step_screen_allday_100_participants.csv')

# Assign the sleep efficiency column
sleep_efficiency_column = "f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday"

# Ensure the date column is in datetime format
df_INS_W1['date'] = pd.to_datetime(df_INS_W1['date'])

# Sort by date to ensure proper order
df_INS_W1 = df_INS_W1.sort_values('date')

# Shift the sleep efficiency by 1 day
df_INS_W1['sleep_efficiency_shifted'] = df_INS_W1[sleep_efficiency_column].shift(-1)

# Filter columns that start with 'f_slp'
columns_f_slp = [col for col in df_INS_W1.columns if col.startswith('f_slp') and col != sleep_efficiency_column]

# Dictionary to store correlations
correlations = {}

# Iterate over each 'f_slp' column and calculate the correlation with the shifted sleep efficiency
for col in columns_f_slp:
    # Drop NaN values for the specific column and shifted sleep efficiency
    df_clean = df_INS_W1[[col, 'sleep_efficiency_shifted']].dropna()

    # Calculate correlation between current column and next day's sleep efficiency
    correlation = df_clean[col].corr(df_clean['sleep_efficiency_shifted'])

    # Store the correlation
    correlations[col] = correlation

    # Plot the relationship for each column
    plt.figure(figsize=(8, 6))
    plt.scatter(df_clean[col], df_clean['sleep_efficiency_shifted'], alpha=0.6)
    plt.title(f'{col} vs Next Day Sleep Efficiency\nAuto-correlation: {correlation:.2f}')
    plt.xlabel(f'{col} (n-th day)')
    plt.ylabel('Sleep Efficiency (n+1-th day) [%]')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Print all calculated correlations
for col, corr_value in correlations.items():
    print(f"Auto-correlation between {col} and Sleep Efficiency (n+1-th day): {corr_value:.2f}")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset df_INS_W1
df_INS_W1 = pd.read_csv('/content/drive/MyDrive/CSE 570 Wireless Project/final_dataset/INS-W_1_sleep_step_screen_allday_100_participants.csv')

# Assign the sleep efficiency column
sleep_efficiency_column = "f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday"

# Ensure the date column is in datetime format
df_INS_W1['date'] = pd.to_datetime(df_INS_W1['date'])

# Sort by date to ensure proper order
df_INS_W1 = df_INS_W1.sort_values('date')

# Shift the sleep efficiency by 1 day
df_INS_W1['sleep_efficiency_shifted'] = df_INS_W1[sleep_efficiency_column].shift(-1)

# Filter columns that start with 'f_slp'
columns_f_slp = [col for col in df_INS_W1.columns if col.startswith('f_steps') and col != sleep_efficiency_column]

# Dictionary to store correlations
correlations = {}

# Iterate over each 'f_slp' column and calculate the correlation with the shifted sleep efficiency
for col in columns_f_slp:
    # Drop NaN values for the specific column and shifted sleep efficiency
    df_clean = df_INS_W1[[col, 'sleep_efficiency_shifted']].dropna()

    # Calculate correlation between current column and next day's sleep efficiency
    correlation = df_clean[col].corr(df_clean['sleep_efficiency_shifted'])

    # Store the correlation
    correlations[col] = correlation

    # Plot the relationship for each column
    plt.figure(figsize=(8, 6))
    plt.scatter(df_clean[col], df_clean['sleep_efficiency_shifted'], alpha=0.6)
    plt.title(f'{col} vs Next Day Sleep Efficiency\nAuto-correlation: {correlation:.2f}')
    plt.xlabel(f'{col} (n-th day)')
    plt.ylabel('Sleep Efficiency (n+1-th day) [%]')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Print all calculated correlations
for col, corr_value in correlations.items():
    print(f"Auto-correlation between {col} and Sleep Efficiency (n+1-th day): {corr_value:.2f}")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mutual_info_score
from scipy.spatial.distance import pdist, squareform
from scipy.stats import pearsonr

# Load the dataset df_INS_W1
df_INS_W1 = pd.read_csv('/content/drive/MyDrive/CSE 570 Wireless Project/final_dataset/INS-W_1_sleep_step_screen_allday_100_participants.csv')

# Assign the sleep efficiency column
sleep_efficiency_column = "f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday"

# Ensure the date column is in datetime format
df_INS_W1['date'] = pd.to_datetime(df_INS_W1['date'])

# Sort by date to ensure proper order
df_INS_W1 = df_INS_W1.sort_values('date')

# Shift the sleep efficiency by 1 day
df_INS_W1['sleep_efficiency_shifted'] = df_INS_W1[sleep_efficiency_column].shift(-1)

# Filter columns that start with 'f_slp'
columns_f_slp = [col for col in df_INS_W1.columns if col.startswith('f_slp') and col != sleep_efficiency_column]

# Define a function to calculate mutual information
def mutual_info(x, y, bins=20):
    c_xy = np.histogram2d(x, y, bins)[0]
    mi = mutual_info_score(None, None, contingency=c_xy)
    return mi

# Define a function to calculate distance correlation
def dist_corr(X, Y):
    X = np.atleast_2d(X).T
    Y = np.atleast_2d(Y).T

    n = X.shape[0]
    A = squareform(pdist(X, metric='euclidean'))
    B = squareform(pdist(Y, metric='euclidean'))

    A -= A.mean(axis=0)[None, :] + A.mean(axis=1)[:, None] - A.mean()
    B -= B.mean(axis=0)[None, :] + B.mean(axis=1)[:, None] - B.mean()

    dcov_AB = np.sum(A * B) / (n ** 2)
    dcov_AA = np.sum(A * A) / (n ** 2)
    dcov_BB = np.sum(B * B) / (n ** 2)

    dcor = np.sqrt(dcov_AB) / np.sqrt(np.sqrt(dcov_AA * dcov_BB))
    return dcor

# Dictionary to store correlations
correlations = {
    'Mutual Information': {},
    'Distance Correlation': {},
}

# Iterate over each 'f_slp' column and calculate non-linear correlations
for col in columns_f_slp:
    # Drop NaN values for the specific column and shifted sleep efficiency
    df_clean = df_INS_W1[[col, 'sleep_efficiency_shifted']].dropna()

    # Calculate mutual information
    mi = mutual_info(df_clean[col], df_clean['sleep_efficiency_shifted'])

    # Calculate distance correlation
    dcor = dist_corr(df_clean[col], df_clean['sleep_efficiency_shifted'])

    # Store the correlations
    correlations['Mutual Information'][col] = mi
    correlations['Distance Correlation'][col] = dcor

    # Plot the relationship for each column
    plt.figure(figsize=(8, 6))
    plt.scatter(df_clean[col], df_clean['sleep_efficiency_shifted'], alpha=0.6)
    plt.title(f'{col} vs Next Day Sleep Efficiency\nMI: {mi:.2f}, DistCorr: {dcor:.2f}')
    plt.xlabel(f'{col} (n-th day)')
    plt.ylabel('Sleep Efficiency (n+1-th day) [%]')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Print all calculated correlations
for method, result in correlations.items():
    print(f"--- {method} ---")
    for col, value in result.items():
        print(f"{col}: {value:.4f}")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C

# Load the dataset df_INS_W1
df_INS_W1 = pd.read_csv('/content/drive/MyDrive/CSE 570 Wireless Project/final_dataset/INS-W_1_sleep_step_screen_allday_100_participants.csv')

# Assign the sleep efficiency column
sleep_efficiency_column = "f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday"

# Ensure the date column is in datetime format
df_INS_W1['date'] = pd.to_datetime(df_INS_W1['date'])

# Sort by date to ensure proper order
df_INS_W1 = df_INS_W1.sort_values('date')

# Shift the sleep efficiency by 1 day
df_INS_W1['sleep_efficiency_shifted'] = df_INS_W1[sleep_efficiency_column].shift(-1)

# Filter columns that start with 'f_slp'
columns_f_slp = [col for col in df_INS_W1.columns if col.startswith('f_slp') and col != sleep_efficiency_column]

# Polynomial regression function
def polynomial_regression(x, y, degree=3):
    poly = PolynomialFeatures(degree)
    x_poly = poly.fit_transform(x)
    model = LinearRegression().fit(x_poly, y)
    return model, poly

# Gaussian process function
def gaussian_process(x, y):
    # Define kernel: constant kernel multiplied by radial basis function kernel
    kernel = C(1.0, (1e-4, 1e1)) * RBF(1.0, (1e-4, 1e1))
    gp = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=10, alpha=1e-2).fit(x, y)
    return gp

# Dictionary to store polynomial regression and GP models
models = {
    'Polynomial Regression': {},
    'Gaussian Process': {},
}

# Iterate over each 'f_slp' column and fit the models
for col in columns_f_slp:
    # Drop NaN values for the specific column and shifted sleep efficiency
    df_clean = df_INS_W1[[col, 'sleep_efficiency_shifted']].dropna()

    # Reshape data for sklearn (as sklearn expects 2D arrays)
    X = df_clean[col].values.reshape(-1, 1)
    y = df_clean['sleep_efficiency_shifted'].values.reshape(-1, 1)

    # Polynomial regression
    poly_model, poly_features = polynomial_regression(X, y, degree=3)
    models['Polynomial Regression'][col] = poly_model

    # Gaussian process
    gp_model = gaussian_process(X, y)
    models['Gaussian Process'][col] = gp_model

    # Generate predictions
    X_plot = np.linspace(min(X), max(X), 100).reshape(-1, 1)
    y_poly_pred = poly_model.predict(poly_features.transform(X_plot))
    y_gp_pred, y_gp_std = gp_model.predict(X_plot, return_std=True)

    # Plot Polynomial Regression
    plt.figure(figsize=(8, 6))
    plt.scatter(X, y, color='blue', alpha=0.6, label='Data')
    plt.plot(X_plot, y_poly_pred, color='green', label='Polynomial Regression', linewidth=2)
    plt.fill_between(X_plot.flatten(), y_gp_pred.flatten() - 2*y_gp_std, y_gp_pred.flatten() + 2*y_gp_std,
                     color='lightgray', alpha=0.5, label='GP 95% Confidence Interval')
    plt.plot(X_plot, y_gp_pred, color='red', label='Gaussian Process', linewidth=2)
    plt.title(f'{col} vs Next Day Sleep Efficiency')
    plt.xlabel(f'{col} (n-th day)')
    plt.ylabel('Sleep Efficiency (n+1-th day) [%]')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Print a summary of the models
for model_type, model_dict in models.items():
    print(f"\n--- {model_type} ---")
    for col, model in model_dict.items():
        print(f"{col}: Model Trained")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-836564ec144e> in <cell line: 48>()
#      59
#      60     # Gaussian process
# ---> 61     gp_model = gaussian_process(X, y)
#      62     models['Gaussian Process'][col] = gp_model
#      63
#
# <ipython-input-25-836564ec144e> in gaussian_process(x, y)
#      36     # Define kernel: constant kernel multiplied by radial basis function kernel
#      37     kernel = C(1.0, (1e-4, 1e1)) * RBF(1.0, (1e-4, 1e1))
# ---> 38     gp = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=10, alpha=1e-2).fit(x, y)
#      39     return gp
#      40
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# ...

# %%
import pandas as pd

# Ensure the 'date' column is in datetime format
sleep_data['date'] = pd.to_datetime(sleep_data['date'])

# Sort data by 'pid' and 'date' to ensure temporal order
sleep_data = sleep_data.sort_values(by=['pid', 'date'])

# Initialize a dictionary to store autocorrelation results for each participant
autocorrelation_results = {}

# Iterate over each participant (pid)
for pid in sleep_data['pid'].unique():
    # Filter the data for the current participant
    subject_data = sleep_data[sleep_data['pid'] == pid].sort_values(by='date')

    # Get sleep efficiency for n-th day and n+1-th day by shifting
    subject_data['lagged_sleep_efficiency'] = subject_data['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'].shift(1)

    # Drop any rows with missing values due to shifting
    subject_data = subject_data.dropna(subset=['lagged_sleep_efficiency', 'f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'])

    if len(subject_data) < 2:
        # Skip participants with insufficient data
        print(f"Skipping PID {pid} due to insufficient data")
        continue

    # Calculate the autocorrelation between n-th day and (n+1)-th day sleep efficiency
    autocorrelation = subject_data['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'].corr(subject_data['lagged_sleep_efficiency'])

    # Store the autocorrelation result
    autocorrelation_results[pid] = autocorrelation

    # Output result for the participant
    print(f"PID: {pid}, Autocorrelation (n-th day vs n+1-th day): {autocorrelation}")

# Filter participants with autocorrelation greater than 0.5
high_autocorrelation_pids = {pid: autocorr for pid, autocorr in autocorrelation_results.items() if autocorr > 0.2}

# Print final autocorrelation results for all participants
print("\nFinal Autocorrelation Results (n-th day vs n+1-th day) for all participants:")
for pid, autocorr in autocorrelation_results.items():
    print(f"PID: {pid}, Autocorrelation: {autocorr}")

# Output the number of participants with autocorrelation greater than 0.5
num_high_autocorr_participants = len(high_autocorrelation_pids)
print(f"\nNumber of participants with autocorrelation greater than 0.5: {num_high_autocorr_participants}")

# Optionally, print the participants with high autocorrelation
print("\nParticipants with autocorrelation greater than 0.5:")
for pid, autocorr in high_autocorrelation_pids.items():
    print(f"PID: {pid}, Autocorrelation: {autocorr}")

# %%
# Filter data for participants with sleep efficiency less than 85%
sleep_data=df_INS_W4.copy()
low_efficiency_data = sleep_data[sleep_data['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'] < 85]

# Display the number of participants with low sleep efficiency
low_efficiency_participants = low_efficiency_data['pid'].unique()
print(f"Number of participants with sleep efficiency < 85%: {len(low_efficiency_participants)}")
# Out:
# Number of participants with sleep efficiency < 85%: 9

# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Define relevant features (activity, screen time, etc.)
selected_features = [
    'f_steps:fitbit_steps_summary_rapids_avgsumsteps:allday',
    'f_steps:fitbit_steps_intraday_rapids_avgdurationactivebout:allday',
    'f_screen:phone_screen_rapids_avgdurationunlock:allday',
    'f_screen:phone_screen_rapids_avgdurationunlock_locmap_home:allday',
]

# Initialize a dictionary to store results
results = {}

# Iterate over each participant (pid)
for pid in sleep_data['pid'].unique():
    # Filter the data for the current participant
    subject_data = sleep_data[sleep_data['pid'] == pid].sort_values(by='date')

    # Filter out rows with missing values for the selected features
    subject_data = subject_data.dropna(subset=selected_features)

    if len(subject_data) < 5:
        # Skip participants with too little data
        print(f"Skipping PID {pid} due to insufficient data")
        continue

    # Define X (features) and y (target)
    X = subject_data[selected_features]
    y = subject_data['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday']

    # Split data into 98% training and 2% testing (temporal order)
    train_size = int(0.98 * len(subject_data))
    X_train, X_test = X[:train_size], X[train_size:]
    y_train, y_test = y[:train_size], y[train_size:]

    # Train the Decision Tree model
    model = DecisionTreeRegressor()
    model.fit(X_train, y_train)

    # Make predictions
    y_pred = model.predict(X_test)

    # Evaluate the model using Mean Squared Error (MSE) and Mean Absolute Error (MAE)
    print(y_test)
    print(y_pred)
    mse = mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)

    # Save the result for this participant
    results[pid] = {'MSE': mse, 'MAE': mae}

    # Output result for the participant
    print(f"PID: {pid}, MSE: {mse}, MAE: {mae}")

# Print final results
print("\nFinal Results (MSE and MAE for each participant):")
for pid, score in results.items():
    print(f"PID: {pid}, MSE: {score['MSE']}, MAE: {score['MAE']}")
# Out:
# 87    96.0
# 88    96.0
# Name: f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday, dtype: float64
# [96. 98.]
# PID: INS-W_1000#INS-W_4, MSE: 2.0, MAE: 1.0
# 176    97.0
# 177    99.0
# Name: f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday, dtype: float64
# [96. 96.]
# PID: INS-W_1003#INS-W_4, MSE: 5.0, MAE: 2.0
# 252    99.0
# 253    96.0
# Name: f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday, dtype: float64
# [98. 99.]
# PID: INS-W_1005#INS-W_4, MSE: 5.0, MAE: 2.0
# 336    100.0
# 337     95.0
# Name: f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday, dtype: float64
# [98. 94.]
# PID: INS-W_1006#INS-W_4, MSE: 2.5, MAE: 1.5
# 423    96.0
# 424    96.0
# Name: f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday, dtype: float64
# [96. 95.]
# PID: INS-W_1007#INS-W_4, MSE: 0.5, MAE: 0.5
# 503    96.0
# 504    96.0
# Name: f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday, dtype: float64
# [94. 97.]
# ...

# %%
import pandas as pd

# Ensure the 'date' column is in datetime format
sleep_data['date'] = pd.to_datetime(sleep_data['date'])

# Sort data by 'pid' and 'date' to ensure temporal order
sleep_data = sleep_data.sort_values(by=['pid', 'date'])

# Initialize a dictionary to store autocorrelation results for each participant
autocorrelation_results = {}

# Iterate over each participant (pid)
for pid in sleep_data['pid'].unique():
    # Filter the data for the current participant
    subject_data = sleep_data[sleep_data['pid'] == pid].sort_values(by='date')

    # Get sleep efficiency for n-th day and n+1-th day by shifting
    subject_data['lagged_sleep_efficiency'] = subject_data['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'].shift(1)

    # Drop any rows with missing values due to shifting
    subject_data = subject_data.dropna(subset=['lagged_sleep_efficiency', 'f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'])

    if len(subject_data) < 2:
        # Skip participants with insufficient data
        print(f"Skipping PID {pid} due to insufficient data")
        continue

    # Calculate the autocorrelation between n-th day and (n+1)-th day sleep efficiency
    autocorrelation = subject_data['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'].corr(subject_data['lagged_sleep_efficiency'])

    # Store the autocorrelation result
    autocorrelation_results[pid] = autocorrelation

    # Output result for the participant
    print(f"PID: {pid}, Autocorrelation (n-th day vs n+1-th day): {autocorrelation}")

# Print final autocorrelation results for all participants
print("\nFinal Autocorrelation Results (n-th day vs n+1-th day) for all participants:")
for pid, autocorr in autocorrelation_results.items():
    print(f"PID: {pid}, Autocorrelation: {autocorr}")
# Out:
# PID: INS-W_1000#INS-W_4, Autocorrelation (n-th day vs n+1-th day): -0.09759072488097859
# PID: INS-W_1003#INS-W_4, Autocorrelation (n-th day vs n+1-th day): 0.202099305228541
# PID: INS-W_1005#INS-W_4, Autocorrelation (n-th day vs n+1-th day): 0.08837846340126379
# PID: INS-W_1006#INS-W_4, Autocorrelation (n-th day vs n+1-th day): -0.041517868495832416
# PID: INS-W_1007#INS-W_4, Autocorrelation (n-th day vs n+1-th day): -0.016410169203299046
# PID: INS-W_1010#INS-W_4, Autocorrelation (n-th day vs n+1-th day): 0.10050901946776168
# PID: INS-W_1011#INS-W_4, Autocorrelation (n-th day vs n+1-th day): 0.05493657825971735
# PID: INS-W_1012#INS-W_4, Autocorrelation (n-th day vs n+1-th day): 0.07772156236867946
# PID: INS-W_1013#INS-W_4, Autocorrelation (n-th day vs n+1-th day): 0.1288311688311688
# PID: INS-W_1016#INS-W_4, Autocorrelation (n-th day vs n+1-th day): 0.28193017155272293
# PID: INS-W_1017#INS-W_4, Autocorrelation (n-th day vs n+1-th day): 0.46479460624174623
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from copy import deepcopy

# Ensure that the 'date' column is converted to datetime in each dataset
for key in dataset_dict_raw_filtered_withna:
    dataset_dict_raw_filtered_withna[key]['date'] = pd.to_datetime(dataset_dict_raw_filtered_withna[key]['date'])

# Create the figure and axes for multiple subplots
fig, axes = plt.subplots(figsize=(10.5, 2.7), ncols=1)

# Loop through each feature (just one in this case)
df_plot_data = {}
for idx_feature, feature in enumerate(scale_dict):
    ax = axes  # Since we have just one plot, no need for multiple axes
    df_plot_data_feature = {}

    for i, ds_key in enumerate(ds_keys):
        ins, phase = ds_key.split("_")
        phase = int(phase)

        # Make a deepcopy of the dataset and filter by the feature and date
        data_tmp = deepcopy(dataset_dict_raw_filtered_withna[ds_key][["date", feature]])

        # Remove outliers (2.5 and 97.5 percentiles)
        low, high = np.nanpercentile(data_tmp[feature], q=[2.5, 97.5])
        data_tmp = data_tmp[(low < data_tmp[feature]) & (data_tmp[feature] < high)]

        # Group by date and compute mean
        data = data_tmp.groupby("date")[feature].mean() / scale_dict[feature]

        # Convert index to datetime if it's not already in that format
        data.index = pd.to_datetime(data.index)

        # Filter the data to fit within the specified date range
        data_in_range = data.loc[(date_range[phase]["start"] <= data.index) & (data.index <= date_range[phase]["end"])]

        # Normalize dates to start from 0 (weeks)
        data_in_range.index = (data_in_range.index - date_range[phase]["start"]).days // 7  # Weekly

        # Store the data in df_plot_data_feature
        df_plot_data_feature[ds_key] = deepcopy(data_in_range)

        # Plot the data for this dataset (line plot)
        data_in_range.plot(ax=ax, color=colors[i], label="Year" + str(phase))

    df_plot_data[feature] = pd.DataFrame(df_plot_data_feature)

    # Customize the x-axis
    ax.set_xticks(nanosecond_xticks)
    ax.set_xticklabels([f"W{i}" for i in range(1, 11)])
    ax.set_xlabel("")

    # Customize the y-axis
    ax.set_ylabel(y_label_dict[feature])
    ax.set_ylim(y_lim_dict[feature])

    # Set the title
    ax.set_title(title_dict[feature])

    # Add vertical lines for weekends
    for x in nanosecond_xticks_weekend:
        ax.axvline(x, linewidth=0.7, color="gray", linestyle=(0, (5, 10)))

    # Remove minor ticks for x-axis
    ax.tick_params(axis="x", which="minor", bottom=False, top=False)

# Add legend
fig.legend(["Year1 / Pre COVID", "Year2 / Pre COVID", "Year3 / Post COVID", "Year4 / Post COVID"], ncol=4, loc="lower center", bbox_to_anchor=(0.5, -0.08))

# Adjust layout and save the figure
plt.tight_layout()
plt.savefig("singlefeat_timeseries_examples_neurips.pdf", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-30c4f33d70de> in <cell line: 6>()
#       4
#       5 # Ensure that the 'date' column is converted to datetime in each dataset
# ----> 6 for key in dataset_dict_raw_filtered_withna:
#       7     dataset_dict_raw_filtered_withna[key]['date'] = pd.to_datetime(dataset_dict_raw_filtered_withna[key]['date'])
#       8
#
# NameError: name 'dataset_dict_raw_filtered_withna' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Function to count participants based on sleep efficiency and group by pid
def count_sleep_efficiency_by_pid(df):
    # Group by pid and calculate the mean sleep efficiency per participant
    pid_mean_efficiency = df.groupby('pid')['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'].mean()

    # Count participants with sleep efficiency >= 85% and < 85%
    high_efficiency_count = (pid_mean_efficiency >= 85).sum()
    low_efficiency_count = (pid_mean_efficiency < 85).sum()

    return high_efficiency_count, low_efficiency_count

# Load the datasets
df_INS_W1 = pd.read_csv('/content/drive/MyDrive/CSE 570 Wireless Project/final_dataset/INS-W_1_sleep_step_screen_allday_100_participants.csv')
df_INS_W2 = pd.read_csv('/content/drive/MyDrive/CSE 570 Wireless Project/final_dataset/INS-W_2_sleep_step_screen_allday_100_participants.csv')
df_INS_W3 = pd.read_csv('/content/drive/MyDrive/CSE 570 Wireless Project/final_dataset/INS-W_3_sleep_step_screen_allday_100_participants.csv')
df_INS_W4 = pd.read_csv('/content/drive/MyDrive/CSE 570 Wireless Project/final_dataset/INS-W_4_sleep_step_screen_allday_100_participants.csv')

# Count the number of participants for each dataset
high_w1, low_w1 = count_sleep_efficiency_by_pid(df_INS_W1)
high_w2, low_w2 = count_sleep_efficiency_by_pid(df_INS_W2)
high_w3, low_w3 = count_sleep_efficiency_by_pid(df_INS_W3)
high_w4, low_w4 = count_sleep_efficiency_by_pid(df_INS_W4)

# Plotting the bar plot
labels = ['INS-W1', 'INS-W2', 'INS-W3', 'INS-W4']
high_efficiency_counts = [high_w1, high_w2, high_w3, high_w4]
low_efficiency_counts = [low_w1, low_w2, low_w3, low_w4]

x = range(len(labels))

plt.figure(figsize=(10, 6))

# Plot high and low efficiency as side-by-side bars
bar_width = 0.35
plt.bar(x, high_efficiency_counts, width=bar_width, label='≥ 85% Sleep Efficiency', color='green', align='center')
plt.bar([i + bar_width for i in x], low_efficiency_counts, width=bar_width, label='< 85% Sleep Efficiency', color='red', align='center')

# Adding labels and title
plt.xlabel('Dataset')
plt.ylabel('Number of Participants')
plt.title('Number of Participants with High and Low Sleep Efficiency Across Datasets')
plt.xticks([i + bar_width / 2 for i in x], labels)
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Combine all datasets into a dictionary for easy iteration
datasets = {
    "INS_W3": df_INS_W3
}

# Define the sleep efficiency column
sleep_efficiency_column = "f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday"

# Define the bins to focus on 85% range and surroundings
bins = np.linspace(60, 100, 15)  # Bins from 60% to 100% in increments

# Plot settings
plt.figure(figsize=(10, 6))

# Iterate over the datasets and plot histograms
for name, dataset in datasets.items():
    # Drop NaN values
    data = dataset[sleep_efficiency_column].dropna()

    # Plot the histogram for each dataset
    plt.hist(data, bins=bins, alpha=0.5, label=name, edgecolor='black')

# Customize the plot
plt.title('Histogram of Sleep Efficiency (with focus around 85%)')
plt.xlabel('Sleep Efficiency (%)')
plt.ylabel('Number of Participants')
plt.grid(True)
plt.legend()

# Highlight the 85% bin
plt.axvline(85, color='red', linestyle='--', label='85% Threshold')

# Display the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

# Define relevant features (activity, screen time, etc.)
sleep_data=df_INS_W4.copy()
selected_features = [
    'f_steps:fitbit_steps_summary_rapids_avgsumsteps:allday',
    'f_steps:fitbit_steps_intraday_rapids_avgdurationactivebout:allday',
    'f_screen:phone_screen_rapids_avgdurationunlock:allday',
    'f_screen:phone_screen_rapids_avgdurationunlock_locmap_home:allday',
]

# Initialize lists to store results for each LOSO iteration
mse_list = []
mae_list = []
deviation_mse_list = []  # To store MSEs for large deviation days

# Perform LOSO (Leave-One-Subject-Out) cross-validation
for pid in sleep_data['pid'].unique():
    # Split data into training (all participants except the current one) and testing (current participant)
    train_data = sleep_data[sleep_data['pid'] != pid]
    test_data = sleep_data[sleep_data['pid'] == pid].sort_values(by='date')

    # Filter out rows with missing values for the selected features
    train_data = train_data.dropna(subset=selected_features)
    test_data = test_data.dropna(subset=selected_features)

    if len(test_data) < 5 or len(train_data) < 5:
        # Skip participants with too little data
        print(f"Skipping PID {pid} due to insufficient data")
        continue

    # Define X (features) and y (target) for train and test sets
    X_train = train_data[selected_features]
    y_train = train_data['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday']
    X_test = test_data[selected_features]
    y_test = test_data['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday']

    # Train the Decision Tree model
    model = DecisionTreeRegressor()
    model.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Find test days where sleep efficiency deviation from the previous day is >= 2
    test_data['sleep_efficiency_diff'] = test_data['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'].diff()
    deviation_days = test_data[test_data['sleep_efficiency_diff'].abs() >= 2]

    # If there are days with large deviation, calculate the MSE for those specific points
    if not deviation_days.empty:
        relative_indices = deviation_days.index - test_data.index[0]
        mse_deviation = mean_squared_error(y_test.iloc[relative_indices], y_pred[relative_indices])
        deviation_mse_list.append(mse_deviation)

    # Calculate MSE and MAE for the current left-out participant
    mse = mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)

    # Store the results
    mse_list.append(mse)
    mae_list.append(mae)

    # Output result for the current participant
    print(f"PID: {pid}, MSE: {mse}, MAE: {mae}")

# Print final results for deviation
if deviation_mse_list:
    avg_deviation_mse = np.mean(deviation_mse_list)
    print(f"\nAverage MSE for points with sleep efficiency deviation >= 2: {avg_deviation_mse}")
else:
    print("No large deviation days were found.")

# Calculate the overall average MSE and MAE across all participants
average_mse_all = np.mean(mse_list)
average_mae_all = np.mean(mae_list)

# Print the average MSE and MAE across all iterations
print(f"\nAverage MSE across all LOSO iterations: {average_mse_all}")
print(f"Average MAE across all LOSO iterations: {average_mae_all}")
# Out:
# PID: INS-W_1000#INS-W_4, MSE: 22.20505617977528, MAE: 2.4101123595505616
# PID: INS-W_1003#INS-W_4, MSE: 22.8876404494382, MAE: 2.4831460674157304
# PID: INS-W_1005#INS-W_4, MSE: 47.95065789473684, MAE: 4.032894736842105
# PID: INS-W_1006#INS-W_4, MSE: 26.038508260447035, MAE: 3.5221088435374153
# PID: INS-W_1007#INS-W_4, MSE: 9.724137931034482, MAE: 1.3793103448275863
# PID: INS-W_1010#INS-W_4, MSE: 15.8625, MAE: 2.6875
# PID: INS-W_1011#INS-W_4, MSE: 16.646341463414632, MAE: 3.2560975609756095
# PID: INS-W_1012#INS-W_4, MSE: 7.181276124907795, MAE: 1.689328743545611
# PID: INS-W_1013#INS-W_4, MSE: 10.329113924050633, MAE: 0.9620253164556962
# PID: INS-W_1016#INS-W_4, MSE: 36.55, MAE: 4.0
# PID: INS-W_1017#INS-W_4, MSE: 19.98876404494382, MAE: 2.4831460674157304
# PID: INS-W_1020#INS-W_4, MSE: 8.185185185185185, MAE: 2.1604938271604937
# PID: INS-W_1021#INS-W_4, MSE: 11.003048780487806, MAE: 2.6036585365853657
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
import pandas as pd
import numpy as np

# Define relevant features (activity, screen time, etc.)
sleep_data = df_INS_W4.copy()
selected_features = [
    'f_steps:fitbit_steps_summary_rapids_avgsumsteps:allday',
    'f_steps:fitbit_steps_intraday_rapids_avgdurationactivebout:allday',
    'f_screen:phone_screen_rapids_avgdurationunlock:allday',
    'f_screen:phone_screen_rapids_avgdurationunlock_locmap_home:allday',
]

# Define bins and labels for classification
bins = [0, 70, 84, 90, 100]  # Bins for sleep efficiency
labels = [0, 1, 2, 3]  # Bin labels for classification

# Apply binning to the target column
sleep_data['efficiency_bin'] = pd.cut(
    sleep_data['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'],
    bins=bins,
    labels=labels,
    right=False,
)

# Initialize lists to store results for each LOSO iteration
accuracy_list = []

# Perform LOSO (Leave-One-Subject-Out) cross-validation
for pid in sleep_data['pid'].unique():
    # Split data into training (all participants except the current one) and testing (current participant)
    train_data = sleep_data[sleep_data['pid'] != pid]
    test_data = sleep_data[sleep_data['pid'] == pid].sort_values(by='date')

    # Filter out rows with missing values for the selected features and target bins
    train_data = train_data.dropna(subset=selected_features + ['efficiency_bin'])
    test_data = test_data.dropna(subset=selected_features + ['efficiency_bin'])

    if len(test_data) < 5 or len(train_data) < 5:
        # Skip participants with too little data
        print(f"Skipping PID {pid} due to insufficient data")
        continue

    # Define X (features) and y (binned target) for train and test sets
    X_train = train_data[selected_features]
    y_train = train_data['efficiency_bin'].astype(int)  # Convert labels to integers for classification
    X_test = test_data[selected_features]
    y_test = test_data['efficiency_bin'].astype(int)

    # Train the Decision Tree Classifier model
    model = DecisionTreeClassifier()
    model.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Calculate accuracy for the current left-out participant
    accuracy = accuracy_score(y_test, y_pred)
    accuracy_list.append(accuracy)

    # Output result for the current participant
    print(f"PID: {pid}, Accuracy: {accuracy}")

# Calculate the overall average accuracy across all participants
average_accuracy_all = np.mean(accuracy_list)

# Print the overall results
print(f"\nAverage Accuracy across all LOSO iterations: {average_accuracy_all}")
# Out:
# PID: INS-W_1000#INS-W_4, Accuracy: 0.9887640449438202
# PID: INS-W_1003#INS-W_4, Accuracy: 0.9662921348314607
# PID: INS-W_1005#INS-W_4, Accuracy: 0.9864864864864865
# PID: INS-W_1006#INS-W_4, Accuracy: 0.9512195121951219
# PID: INS-W_1007#INS-W_4, Accuracy: 0.9770114942528736
# PID: INS-W_1010#INS-W_4, Accuracy: 0.9875
# PID: INS-W_1011#INS-W_4, Accuracy: 0.8414634146341463
# PID: INS-W_1012#INS-W_4, Accuracy: 1.0
# PID: INS-W_1013#INS-W_4, Accuracy: 0.9873417721518988
# PID: INS-W_1016#INS-W_4, Accuracy: 0.9
# PID: INS-W_1017#INS-W_4, Accuracy: 0.898876404494382
# PID: INS-W_1020#INS-W_4, Accuracy: 0.9876543209876543
# PID: INS-W_1021#INS-W_4, Accuracy: 0.9113924050632911
# PID: INS-W_1025#INS-W_4, Accuracy: 0.9135802469135802
# PID: INS-W_1027#INS-W_4, Accuracy: 0.1728395061728395
# PID: INS-W_1029#INS-W_4, Accuracy: 0.9620253164556962
# PID: INS-W_1030#INS-W_4, Accuracy: 0.926829268292683
# PID: INS-W_1032#INS-W_4, Accuracy: 1.0
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# Choose classifier: RandomForest, Logistic Regression, or SVM
classifier_choice = "RandomForest"  # Options: "RandomForest", "LogisticRegression", "SVM"

# Initialize lists to store results for each LOSO iteration
accuracy_list = []

# Perform LOSO (Leave-One-Subject-Out) cross-validation
for pid in sleep_data['pid'].unique():
    # Split data into training (all participants except the current one) and testing (current participant)
    train_data = sleep_data[sleep_data['pid'] != pid]
    test_data = sleep_data[sleep_data['pid'] == pid].sort_values(by='date')

    # Filter out rows with missing values for the selected features and target bins
    train_data = train_data.dropna(subset=selected_features + ['efficiency_bin'])
    test_data = test_data.dropna(subset=selected_features + ['efficiency_bin'])

    if len(test_data) < 5 or len(train_data) < 5:
        # Skip participants with too little data
        print(f"Skipping PID {pid} due to insufficient data")
        continue

    # Define X (features) and y (binned target) for train and test sets
    X_train = train_data[selected_features]
    y_train = train_data['efficiency_bin'].astype(int)  # Convert labels to integers for classification
    X_test = test_data[selected_features]
    y_test = test_data['efficiency_bin'].astype(int)

    # Initialize classifier
    if classifier_choice == "RandomForest":
        model = RandomForestClassifier(n_estimators=100, random_state=42)
    elif classifier_choice == "LogisticRegression":
        model = LogisticRegression(max_iter=1000, random_state=42)
    elif classifier_choice == "SVM":
        model = SVC(kernel='linear', random_state=42)
    else:
        raise ValueError("Invalid classifier choice! Choose from 'RandomForest', 'LogisticRegression', or 'SVM'.")

    # Train the model
    model.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Calculate accuracy for the current left-out participant
    accuracy = accuracy_score(y_test, y_pred)
    accuracy_list.append(accuracy)

    # Output result for the current participant
    print(f"PID: {pid}, Accuracy: {accuracy}")

# Calculate the overall average accuracy across all participants
average_accuracy_all = np.mean(accuracy_list)

# Print the overall results
print(f"\nAverage Accuracy across all LOSO iterations with {classifier_choice}: {average_accuracy_all}")
# Out:
# PID: INS-W_1000#INS-W_4, Accuracy: 1.0
# PID: INS-W_1003#INS-W_4, Accuracy: 0.9887640449438202
# PID: INS-W_1005#INS-W_4, Accuracy: 1.0
# PID: INS-W_1006#INS-W_4, Accuracy: 0.9878048780487805
# PID: INS-W_1007#INS-W_4, Accuracy: 1.0
# PID: INS-W_1010#INS-W_4, Accuracy: 0.9875
# PID: INS-W_1011#INS-W_4, Accuracy: 0.9024390243902439
# PID: INS-W_1012#INS-W_4, Accuracy: 1.0
# PID: INS-W_1013#INS-W_4, Accuracy: 1.0
# PID: INS-W_1016#INS-W_4, Accuracy: 0.925
# PID: INS-W_1017#INS-W_4, Accuracy: 0.898876404494382
# PID: INS-W_1020#INS-W_4, Accuracy: 1.0
# PID: INS-W_1021#INS-W_4, Accuracy: 0.9746835443037974
# PID: INS-W_1025#INS-W_4, Accuracy: 1.0
# PID: INS-W_1027#INS-W_4, Accuracy: 0.18518518518518517
# PID: INS-W_1029#INS-W_4, Accuracy: 1.0
# PID: INS-W_1030#INS-W_4, Accuracy: 0.9878048780487805
# PID: INS-W_1032#INS-W_4, Accuracy: 1.0
# PID: INS-W_1033#INS-W_4, Accuracy: 0.9878048780487805
# PID: INS-W_1034#INS-W_4, Accuracy: 0.9885057471264368
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
import pandas as pd
import numpy as np

# Define relevant features (activity, screen time, etc.)
sleep_data = df_INS_W4.copy()
selected_features = [
    'f_steps:fitbit_steps_summary_rapids_avgsumsteps:allday',
    'f_steps:fitbit_steps_intraday_rapids_avgdurationactivebout:allday',
    'f_screen:phone_screen_rapids_avgdurationunlock:allday',
    'f_screen:phone_screen_rapids_avgdurationunlock_locmap_home:allday',
]

# Define bins and labels for classification
bins = [0, 70, 84, 90, 100]  # Bins for sleep efficiency
labels = [0, 1, 2, 3]  # Bin labels for classification

# Apply binning to the target column
sleep_data['efficiency_bin'] = pd.cut(
    sleep_data['f_slp:fitbit_sleep_summary_rapids_avgefficiencymain:allday'],
    bins=bins,
    labels=labels,
    right=False,
).astype("category")

# Add previous bin as a feature for temporal dependency
sleep_data['previous_bin'] = sleep_data.groupby('pid')['efficiency_bin'].shift(1)

# Drop rows where `efficiency_bin` or `previous_bin` is NaN
sleep_data = sleep_data.dropna(subset=['efficiency_bin', 'previous_bin'])

# Convert bins to integers for calculation
sleep_data['efficiency_bin'] = sleep_data['efficiency_bin'].astype(int)
sleep_data['previous_bin'] = sleep_data['previous_bin'].astype(int)

# Initialize lists to store results for each LOSO iteration
accuracy_list = []

# Perform LOSO (Leave-One-Subject-Out) cross-validation
for pid in sleep_data['pid'].unique():
    # Split data into training (all participants except the current one) and testing (current participant)
    train_data = sleep_data[sleep_data['pid'] != pid]
    test_data = sleep_data[sleep_data['pid'] == pid].sort_values(by='date')

    # Filter out rows with missing values for the selected features
    train_data = train_data.dropna(subset=selected_features)
    test_data = test_data.dropna(subset=selected_features)

    if len(test_data) < 5 or len(train_data) < 5:
        # Skip participants with too little data
        print(f"Skipping PID {pid} due to insufficient data")
        continue

    # Define X (features) and y (bin change) for train and test sets
    train_data['bin_change'] = (
        train_data['efficiency_bin'] - train_data['previous_bin']
    )
    test_data['bin_change'] = (
        test_data['efficiency_bin'] - test_data['previous_bin']
    )

    X_train = train_data[selected_features + ['previous_bin']]
    y_train = train_data['bin_change']
    X_test = test_data[selected_features + ['previous_bin']]
    y_test = test_data['bin_change']

    # Train the Random Forest Classifier model
    model = RandomForestClassifier(n_estimators=100, random_state=42)
    model.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Calculate accuracy for the current left-out participant
    accuracy = accuracy_score(y_test, y_pred)
    accuracy_list.append(accuracy)

    # Output result for the current participant
    print(f"PID: {pid}, Accuracy: {accuracy}")
    print(classification_report(y_test, y_pred, zero_division=0))

# Calculate the overall average accuracy across all participants
average_accuracy_all = np.mean(accuracy_list)

# Print the overall results
print(f"\nAverage Accuracy across all LOSO iterations for bin change prediction: {average_accuracy_all}")
# Out:
# PID: INS-W_1000#INS-W_4, Accuracy: 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        88
#
#     accuracy                           1.00        88
#    macro avg       1.00      1.00      1.00        88
# weighted avg       1.00      1.00      1.00        88
#
# PID: INS-W_1003#INS-W_4, Accuracy: 0.9886363636363636
#               precision    recall  f1-score   support
#
#           -1       0.00      0.00      0.00         1
#            0       0.99      1.00      0.99        86
#            1       1.00      1.00      1.00         1
#
#     accuracy                           0.99        88
#    macro avg       0.66      0.67      0.66        88
# weighted avg       0.98      0.99      0.98        88
#
# PID: INS-W_1005#INS-W_4, Accuracy: 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        71
#
#     accuracy                           1.00        71
# ...

# %%
import pandas as pd

# Copy the data for creating the anomaly column
anomaly_data = sleep_data.copy()

# Calculate bin change for each row
anomaly_data['bin_change'] = anomaly_data['efficiency_bin'] - anomaly_data['previous_bin']

# Define the anomaly column (1 for decrease, 0 for same or increase)
anomaly_data['anomaly'] = anomaly_data['bin_change'].apply(lambda x: 1 if x < 0 else 0)

# Save the result to a CSV file
anomaly_data[['pid', 'date', 'efficiency_bin', 'previous_bin', 'bin_change', 'anomaly']].to_csv('anomaly_detection.csv', index=False)

print("Anomaly detection results have been saved to 'anomaly_detection.csv'.")
